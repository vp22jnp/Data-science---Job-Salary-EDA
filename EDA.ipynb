# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Data Science Jobs Salaries.csv')

# %%
df.head()
# Out:
#   work_year experience_level employment_type                  job_title  \
# 0     2021e               EN              FT    Data Science Consultant
# 1      2020               SE              FT             Data Scientist
# 2     2021e               EX              FT       Head of Data Science
# 3     2021e               EX              FT               Head of Data
# 4     2021e               EN              FT  Machine Learning Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   54000             EUR          64369                 DE            50
# 1   60000             EUR          68428                 GR           100
# 2   85000             USD          85000                 RU             0
# 3  230000             USD         230000                 RU            50
# 4  125000             USD         125000                 US           100
#
#   company_location company_size
# 0               DE            L
# 1               US            L
# 2               RU            M
# 3               RU            L
# 4               US            S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245 entries, 0 to 244
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           245 non-null    object
#  1   experience_level    245 non-null    object
#  2   employment_type     245 non-null    object
#  3   job_title           245 non-null    object
#  4   salary              245 non-null    int64
#  5   salary_currency     245 non-null    object
#  6   salary_in_usd       245 non-null    int64
#  7   employee_residence  245 non-null    object
#  8   remote_ratio        245 non-null    int64
#  9   company_location    245 non-null    object
#  10  company_size        245 non-null    object
# dtypes: int64(3), object(8)
# memory usage: 21.2+ KB

# %%
df.describe()
# Out:
#              salary  salary_in_usd  remote_ratio
# count  2.450000e+02     245.000000    245.000000
# mean   5.025418e+05   99868.012245     69.183673
# std    2.276230e+06   83983.326949     37.593421
# min    4.000000e+03    2876.000000      0.000000
# 25%    6.000000e+04   45896.000000     50.000000
# 50%    1.030000e+05   81000.000000    100.000000
# 75%    1.740000e+05  130000.000000    100.000000
# max    3.040000e+07  600000.000000    100.000000

# %%
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
t=pd.pivot_table(df,values = 'salary_in_usd',
               columns=['experience_level'],
               index=['job_title'],
               aggfunc= np.median)
data=pd.DataFrame(t)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_13808\3412353460.py:1: FutureWarning: The provided callable <function median at 0x0000024FAEB994E0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   t=pd.pivot_table(df,values = 'salary_in_usd',

# %%
data
# Out:
# experience_level                                EN        EX        MI  \
# job_title
# 3D Computer Vision Researcher                  NaN       NaN    5423.0
# AI Scientist                               15051.0       NaN       NaN
# Applied Data Scientist                         NaN       NaN   54376.0
# Applied Machine Learning Scientist             NaN       NaN  423000.0
# BI Data Analyst                             9272.0  150000.0   98000.0
# Big Data Architect                             NaN       NaN       NaN
# Big Data Engineer                          11084.5       NaN   20335.5
# Business Data Analyst                      79800.5       NaN  135000.0
# Cloud Data Engineer                            NaN       NaN   89514.0
# Computer Vision Engineer                   28850.0       NaN       NaN
# Computer Vision Software Engineer          70000.0       NaN   96554.0
# Data Analyst                               66000.0       NaN   68500.0
# Data Analytics Engineer                        NaN       NaN  110000.0
# Data Analytics Manager                         NaN       NaN       NaN
# Data Architect                                 NaN       NaN  180000.0
# Data Engineer                              41689.0       NaN   73377.5
# Data Engineering Manager                       NaN   79833.0       NaN
# Data Science Consultant                    77481.0   70329.0  103000.0
# Data Science Engineer                          NaN       NaN   40529.0
# Data Science Manager                           NaN       NaN       NaN
# Data Scientist                             39916.0       NaN   62726.0
# Data Specialist                                NaN       NaN       NaN
# Director of Data Engineering                   NaN       NaN       NaN
# Director of Data Science                       NaN  154963.0       NaN
# Finance Data Analyst                           NaN       NaN       NaN
# Financial Data Analyst                         NaN       NaN  450000.0
# Head of Data                                   NaN  232500.0       NaN
# Head of Data Science                           NaN   85000.0  110000.0
# Lead Data Analyst                              NaN       NaN   53330.5
# Lead Data Engineer                             NaN       NaN   56000.0
# Lead Data Scientist                            NaN       NaN  115000.0
# ML Engineer                                15966.0       NaN  270000.0
# Machine Learning Engineer                  85000.0       NaN   47405.0
# Machine Learning Infrastructure Engineer       NaN       NaN   50180.0
# Machine Learning Scientist                225000.0       NaN   12000.0
# Manager Data Science                           NaN       NaN       NaN
# Marketing Data Analyst                         NaN       NaN       NaN
# Principal Data Analyst                         NaN       NaN       NaN
# Principal Data Engineer                        NaN  600000.0       NaN
# Principal Data Scientist                       NaN  416000.0  151000.0
# Product Data Analyst                           NaN       NaN    6072.0
# Research Scientist                         83000.0       NaN  125944.0
# Staff Data Scientist                           NaN       NaN       NaN
#
# experience_level                                SE
# job_title
# 3D Computer Vision Researcher                  NaN
# AI Scientist                               55000.0
# Applied Data Scientist                         NaN
# Applied Machine Learning Scientist             NaN
# BI Data Analyst                                NaN
# Big Data Architect                         99956.0
# Big Data Engineer                         111535.5
# Business Data Analyst                          NaN
# Cloud Data Engineer                       160000.0
# Computer Vision Engineer                   39526.0
# Computer Vision Software Engineer              NaN
# Data Analyst                               75984.0
# Data Analytics Engineer                    64933.0
# Data Analytics Manager                    120000.0
# Data Architect                                 NaN
# Data Engineer                             115000.0
# Data Engineering Manager                  163500.0
# Data Science Consultant                        NaN
# Data Science Engineer                     127543.0
# Data Science Manager                      152000.0
# Data Scientist                             91237.0
# Data Specialist                           165000.0
# Director of Data Engineering              157062.5
# Director of Data Science                  168000.0
# Finance Data Analyst                       62250.0
# Financial Data Analyst                         NaN
# Head of Data                                   NaN
# Head of Data Science                           NaN
# Lead Data Analyst                         170000.0
# Lead Data Engineer                        142500.0
# Lead Data Scientist                       190000.0
# ML Engineer                               256000.0
# Machine Learning Engineer                  95362.0
# Machine Learning Infrastructure Engineer  195000.0
# Machine Learning Scientist                242500.0
# Manager Data Science                      144000.0
# Marketing Data Analyst                     89402.0
# Principal Data Analyst                    170000.0
# Principal Data Engineer                   185000.0
# Principal Data Scientist                  175228.0
# Product Data Analyst                           NaN
# Research Scientist                         61270.0
# Staff Data Scientist                      105000.0

# %%
df.head()
# Out:
#   work_year experience_level employment_type                  job_title  \
# 0     2021e               EN              FT    Data Science Consultant
# 1      2020               SE              FT             Data Scientist
# 2     2021e               EX              FT       Head of Data Science
# 3     2021e               EX              FT               Head of Data
# 4     2021e               EN              FT  Machine Learning Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   54000             EUR          64369                 DE            50
# 1   60000             EUR          68428                 GR           100
# 2   85000             USD          85000                 RU             0
# 3  230000             USD         230000                 RU            50
# 4  125000             USD         125000                 US           100
#
#   company_location company_size
# 0               DE            L
# 1               US            L
# 2               RU            M
# 3               RU            L
# 4               US            S

# %% [markdown]
# # Mean salary of each employee

# %%
arr=np.array(df.groupby('experience_level').salary.median())
exp_lev=np.array(['EN','EX','MI','SE'])
fig, ax=plt.subplots()
ax.bar(exp_lev,arr)
ax.set_title("Mean salary by each experience level",fontdict={'size':16,'color':'red'})
ax.set_xlabel("Experience level",fontdict={'size':13,'color':'red'})
ax.set_ylabel("Salary",fontdict={'size':13,'color':'red'})
#ax.grid()
fig.set_size_inches(8,8)
plt.show()

# %% [markdown]
# # Distribution curve of salary in USD

# %%
g=sns.displot(data=df,x='salary_in_usd',kind='kde',legend=True)
plt.title('Distributuon of salary is USD')
g.fig.set_figwidth(10)
g.fig.set_figheight(6)

# %% [markdown]
# # Distributuion of salary in INR

# %%
g=sns.displot (data=df ,x='salary', kind ='kde', legend = True)
plt.title('Distribution of salary in INR')
g.fig.set_figwidth(10)
g.fig.set_figheight(6)

# %% [markdown]
# # Salary shown in Histogram

# %%
g = sns.displot(x=df['salary_in_usd'], data=df , kde=True)
plt.title('Distribution of salary in USD')
g.fig.set_figwidth(10)
g.fig.set_figheight(6)

# %% [markdown]
# # Exp level Vs remote ratio

# %%
g =sns.catplot(data= df , x='experience_level' ,	y='remote_ratio')
g.fig.set_figwidth=(10)
g.fig.set_figheight(6)

# %% [markdown]
# # Salary in USD for each type of emplyment

# %%
df.head(2)
# Out:
#   work_year experience_level employment_type                job_title  salary  \
# 0     2021e               EN              FT  Data Science Consultant   54000
# 1      2020               SE              FT           Data Scientist   60000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             EUR          64369                 DE            50
# 1             EUR          68428                 GR           100
#
#   company_location company_size
# 0               DE            L
# 1               US            L

# %%
g=sns.catplot (data=df , x='experience_level', y='salary_in_usd')
g.fig.set_figwidth(6)
g.fig.set_figheight(6)

# %% [markdown]
# # Salary in USD for each type of employment

# %%
g= sns.catplot (data=df , x='employment_type', y='salary_in_usd')
g.fig.set_figwidth(10)
g.fig.set_figheight(6)

# %% [markdown]
# # Top 5 Employee residence with highest salary paid

# %%
emp_res = df.groupby('employee_residence').salary_in_usd.mean().sort_values(ascending=False)
emp_res=emp_res.head()
plt.figure(figsize=(10,5.5))
sns.barplot(x=emp_res.index,y=emp_res.values)
plt.title('highest salary by employees residence')
plt.ylabel('salary_in_usd')
plt.show()

# %% [markdown]
# # Last 5 employees with leat salary paid

# %%
res = df.groupby('employee_residence').salary_in_usd.mean().sort_values(ascending=True)
res = res.head()
plt.figure(figsize=(10,10))
sns.barplot(x=res.index, y=res.values)
plt.title('lowest salary by employee residence')
plt.ylabel('salary in USD')
plt.show()

# %% [markdown]
# # Salary paid by company size

# %%
sns.catplot (data = df , x='company_size', y='salary')
g.fig.set_figwidth(10)
g.fig.set_figheight(6)

# %%
plt.figure(figsize=(10,6))
sns.stripplot(x=df['company_size'], y=df['salary_in_usd'], data=df).set_title('Salary by company size')
# Out:
# Text(0.5, 1.0, 'Salary by company size')

# %%
sns.stripplot(data = df , x='company_size', y='salary')
#sns.stripplot.set_title('Salary by company size')
plt.figure(figsize=(10,6))

# %% [markdown]
# # Salary Paid at eac remote ratio

# %%
df.head(1)
# Out:
#   work_year experience_level employment_type                job_title  salary  \
# 0     2021e               EN              FT  Data Science Consultant   54000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             EUR          64369                 DE            50
#
#   company_location company_size
# 0               DE            L

# %%
sns.stripplot(data=df, x='remote_ratio',y='salary').set_title('Salary paid at remote area')
plt.figure(figsize=(10,6))

# %%
sns.stripplot(data=df, x='remote_ratio',y='salary_in_usd').set_title('Salary paid at remote area')
plt.figure(figsize=(10,6))

# %% [markdown]
# # 11. Relative share of employees by remote work

# %%
remo=np.array(df['remote_ratio'].value_counts(sort=True))
labels=['Full remote', 'Partial remote', 'No remote']
plt.figure(figsize=(6,6))
plt.pie(remo, labels=labels, shadow=True, frame=True)
plt.legend()
plt.title('employees by remote ratio')
plt.show()

# %%
df.head(1)
# Out:
#   work_year experience_level employment_type                job_title  salary  \
# 0     2021e               EN              FT  Data Science Consultant   54000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             EUR          64369                 DE            50
#
#   company_location company_size
# 0               DE            L

# %% [markdown]
# # Employees by Job_title

# %%
job_Title=np.array(df['job_title'].value_counts(sort=True))
#job_Title=df.head()
#labels=['Full remote', 'Partial remote', 'No remote']
plt.figure(figsize=(6,6))
plt.pie(job_Title, shadow=True, frame=True)
plt.legend()
plt.title('more job titles')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # 12. Relative share of employees by company size

# %%
df.head(1)
# Out:
#   work_year experience_level employment_type                job_title  salary  \
# 0     2021e               EN              FT  Data Science Consultant   54000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             EUR          64369                 DE            50
#
#   company_location company_size
# 0               DE            L

# %%
coms = df['company_size'].value_counts(sort=False)
print(coms)
Labels = [x for x in df['company_size'].unique()]
print('the company size labels are: ', Labels)
plt.figure(figsize=(6,6))
plt.pie(coms.values, labels=Labels, shadow=True, frame=True)
plt.legend()
plt.title('employees by company size')
plt.show()
# Out:
# company_size
# L    132
# M     55
# S     58
# Name: count, dtype: int64
# the company size labels are:  ['L', 'M', 'S']

# %% [markdown]
# # 13. Pivot table of maximum salary by company size and remote ratio

# %%
df.head(1)
# Out:
#   work_year experience_level employment_type                job_title  salary  \
# 0     2021e               EN              FT  Data Science Consultant   54000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             EUR          64369                 DE            50
#
#   company_location company_size
# 0               DE            L

# %%
t=pd.pivot_table(df,
                values='salary_in_usd',
                index='remote_ratio',
                 columns='company_size',
                 aggfunc= np.max
                   )
pd.DataFrame(t)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_13808\4050756976.py:1: FutureWarning: The provided callable <function max at 0x0000024FAEA65DA0> is currently using DataFrameGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   t=pd.pivot_table(df,
# company_size       L       M       S
# remote_ratio
# 0             276000  450000  260000
# 50            423000  109024  160000
# 100           600000  195000  416000

# %% [markdown]
# # Number of eployees by year of joining

# %%
plt.figure(figsize=(7,7))
sns.countplot(x=df['work_year'], data=df)
plt.title('Number of employees by year of joining')
plt.show()

# %%
plt.figure(figsize=(7,7))
sns.countplot(data=df,x='work_year')
plt.title('Number of employees by year of joining')
plt.show()

# %%
df.isnull().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %% [markdown]
# # Number of employees by Exp. level, Employment type, Company size and Remote ratio

# %%
#columns = ['experience_level','employment_type','company_size','remote_ratio']

ex =df['experience_level'].value_counts()

em =df['employment_type'].value_counts()

co =df['company_size'].value_counts()

re =df['remote_ratio'].map({100:'Full remote',
                           50:'Partial remote',
                           0:'No remote'}).value_counts()


fig, axs = plt.subplots(2,2, figsize=(10,10))

axs[0,0].bar(ex.index,ex.values)
axs[0,0].set_xlabel('Experience level')
axs[0,0].set_ylabel('Number of employees')


axs[0,1].bar(em.index,em.values)
axs[0,1].set_xlabel('Employment type')
axs[0,1].set_ylabel('Number of employees')


axs[1,0].bar(co.index,co.values)
axs[1,0].set_xlabel('company size')
axs[1,0].set_ylabel('Number of employees')


axs[1,1].bar(re.index,re.values)
axs[1,1].set_xlabel('Remote ratio')
axs[1,1].set_ylabel('Number of employees')

plt.suptitle('Number of employees by Exp. level, Employment type, Company size and Remote ratio')
fig.tight_layout()
plt.show()

# %% [markdown]
# # 19. Distribution of employees by experience level and company size

# %%
def swarm_plot(x, y, hue, data=df):
    plt.figure(figsize=(6,6))
    sns.swarmplot(x=x, y=y, hue=hue,data=df)
    plt.show
    
plt.figure(figsize=(8,8))
sns.swarmplot(x=df['experience_level'],
              y=df['salary_in_usd'],
              hue=df['company_size'],
              data=df)
plt.title("Distribution of employees by experience level and company size")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # 20. Distribution of employees by salaries

# %%
def strip_plot(x, y, hue, data=df):
    plt.figure(figsize=(6,6))
    sns.stripplot(x=x, y=y, hue=hue,data=df)
    plt.show
    
    
strip_plot(df['experience_level'],df['salary_in_usd'],df['company_size'], data=df)
strip_plot(df['employment_type'],df['salary_in_usd'],df['company_size'],data=df)
strip_plot(df['experience_level'],df['salary_in_usd'],df['remote_ratio'], data=df)
strip_plot(df['employment_type'],df['salary_in_usd'],df['remote_ratio'],data=df)
